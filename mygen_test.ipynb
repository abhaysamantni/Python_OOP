# %%
import mygen

n1=mygen.MyGen()
print(n1)
# Out:
# <generator object MyGen at 0x0000021950CE16D0>

# %%
print(next(n1))
# Out:
# This is printed first
# This is printed second
# 3

# %%
print(next(n1))
# Out:
# This is printed at third
# 5

# %%
print(next(n1))
# Out:
# This is printed at fourth
# 7

# %%
n2=mygen.MyGen()
print(n2)
# Out:
# <generator object MyGen at 0x0000021950CE1C10>

# %%
print(next(n1))
# Out:
# This is printed at last
# 9

# %%
print(next(n1))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(next(n1))
#
# StopIteration:

# %%
print(next(n2))
